# %%
import numpy as np
import pandas as pd

from pm4py.algo.simulation.tree_generator import factory as tree_gen_factory
from pm4py.objects.process_tree import semantics
from pm4py.visualization.process_tree import factory as pt_vis_factory
from pm4py.objects.conversion.process_tree import factory as pt_conv_factory
from pm4py.visualization.petrinet import factory as pn_vis_factory
from pm4py.algo.discovery.inductive import factory as inductive_miner
from pm4py.algo.discovery.alpha import factory as alpha_miner
from pm4py.objects.log.exporter.xes import factory as xes_exporter
from pm4py.objects.conversion.log import factory as conversion_factory
from pm4py.objects.log.importer.xes import factory as xes_import_factory


import DiscTest

# %% [markdown]
# Choose parameters for the Process Tree

# %%
FileNameGTlog = "GTlog-6.xes"
FileNameAlpha = "alpha-6.pnml"
FileNameInduct0 = "ind0-6.pnml"
FileNameInduct1 = "ind1-6.pnml"
FileNameILP = "ilp-6.pnml"

# %%
firstlog = xes_import_factory.apply(FileNameGTlog)

# %%
def log_converter(logdummy):
    outputlog = []
    for i in range(len(logdummy)):
        dummytrace = []
        for j in range(len(logdummy[i])):
            dummytrace.append(logdummy[i][j]['concept:name'].replace(" ", ""))
        outputlog.append(dummytrace)
    return(outputlog)

# %%
GT_log = log_converter(firstlog)

# %% [markdown]
# # alpha

# %%
DiscTest.perform_test(GT_log, FileNameAlpha, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # Inductive 0

# %%
DiscTest.perform_test(GT_log, FileNameInduct0, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # Inductive 1

# %%
DiscTest.perform_test(GT_log, FileNameInduct1, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # ILP

# %%
DiscTest.perform_test(GT_log, FileNameILP, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %%
FileNameGTlog = "GTlog-8.xes"
FileNameAlpha = "alpha-8.pnml"
FileNameInduct0 = "ind0-8.pnml"
FileNameInduct1 = "ind1-8.pnml"
FileNameILP = "ilp-8.pnml"

# %%
firstlog = xes_import_factory.apply(FileNameGTlog)

# %%
def log_converter(logdummy):
    outputlog = []
    for i in range(len(logdummy)):
        dummytrace = []
        for j in range(len(logdummy[i])):
            dummytrace.append(logdummy[i][j]['concept:name'].replace(" ", ""))
        outputlog.append(dummytrace)
    return(outputlog)

# %%
GT_log = log_converter(firstlog)

# %% [markdown]
# # alpha

# %%
#DiscTest.perform_test(GT_log, FileNameAlpha, 3)

# %% [markdown]
# # Inductive 0

# %%
DiscTest.perform_test(GT_log, FileNameInduct0, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # Inductive 1

# %%
DiscTest.perform_test(GT_log, FileNameInduct1, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # ILP

# %%
DiscTest.perform_test(GT_log, FileNameILP, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %%
FileNameGTlog = "GTlog-10.xes"
FileNameAlpha = "alpha-10.pnml"
FileNameInduct0 = "ind0-10.pnml"
FileNameInduct1 = "ind1-10.pnml"
FileNameILP = "ilp-10.pnml"

# %%
firstlog = xes_import_factory.apply(FileNameGTlog)

# %%
def log_converter(logdummy):
    outputlog = []
    for i in range(len(logdummy)):
        dummytrace = []
        for j in range(len(logdummy[i])):
            dummytrace.append(logdummy[i][j]['concept:name'].replace(" ", ""))
        outputlog.append(dummytrace)
    return(outputlog)

# %%
GT_log = log_converter(firstlog)

# %% [markdown]
# # alpha

# %%
DiscTest.perform_test(GT_log, FileNameAlpha, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # Inductive 0

# %%
DiscTest.perform_test(GT_log, FileNameInduct0, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # Inductive 1

# %%
DiscTest.perform_test(GT_log, FileNameInduct1, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # ILP

# %%
DiscTest.perform_test(GT_log, FileNameILP, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %%
FileNameGTlog = "GTlog-12.xes"
FileNameAlpha = "alpha-12.pnml"
FileNameInduct0 = "ind0-12.pnml"
FileNameInduct1 = "ind1-12.pnml"
FileNameILP = "ilp-12.pnml"

# %%
firstlog = xes_import_factory.apply(FileNameGTlog)

# %%
def log_converter(logdummy):
    outputlog = []
    for i in range(len(logdummy)):
        dummytrace = []
        for j in range(len(logdummy[i])):
            dummytrace.append(logdummy[i][j]['concept:name'].replace(" ", ""))
        outputlog.append(dummytrace)
    return(outputlog)

# %%
GT_log = log_converter(firstlog)

# %% [markdown]
# # alpha

# %%
#DiscTest.perform_test(GT_log, FileNameAlpha, 3)

# %% [markdown]
# # Inductive 0

# %%
DiscTest.perform_test(GT_log, FileNameInduct0, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # Inductive 1

# %%
DiscTest.perform_test(GT_log, FileNameInduct1, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...

# %% [markdown]
# # ILP

# %%
DiscTest.perform_test(GT_log, FileNameILP, 3)
# Out:
# [*] Generating traces (randomly)...
#
# [*] At trace #0
#
#  [progress] 0 / 0 / 1001
#
#  [progress] 0 / 10 / 1001
#
#  [progress] 0 / 20 / 1001
#
#  [progress] 0 / 30 / 1001
#
#  [progress] 0 / 40 / 1001
#
#  [progress] 0 / 50 / 1001
#
#  [progress] 0 / 60 / 1001
#
#  [progress] 0 / 70 / 1001
#
#  [progress] 0 / 80 / 1001
#
#  [progress] 0 / 90 / 1001
#
# [*] At trace #100
#
#  [progress] 0 / 100 / 1001
#
#  [progress] 0 / 110 / 1001
#
#  [progress] 0 / 120 / 1001
#
#  [progress] 0 / 130 / 1001
#
#  [progress] 0 / 140 / 1001
#
#  [progress] 0 / 150 / 1001
#
#  [progress] 0 / 160 / 1001
#
#  [progress] 0 / 170 / 1001
#
#  [progress] 0 / 180 / 1001
#
#  [progress] 0 / 190 / 1001
#
# [*] At trace #200
#
#  [progress] 0 / 200 / 1001
#
#  [progress] 0 / 210 / 1001
#
#  [progress] 0 / 220 / 1001
#
#  [progress] 0 / 230 / 1001
#
#  [progress] 0 / 240 / 1001
#
#  [progress] 0 / 250 / 1001
#
#  [progress] 0 / 260 / 1001
#
#  [progress] 0 / 270 / 1001
#
#  [progress] 0 / 280 / 1001
#
# ...
